# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib
import numpy as np
# Import the API key.
from config import weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %% [markdown]
# ## Create 2000 Random Cities

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
import requests

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %% [markdown]
# ## API CALL

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3c9f90f5546dd92066ec3d4267557b20

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ridgefield
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | fairbanks
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | la ronge
# Processing Record 9 of Set 1 | chumikan
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | poum
# Processing Record 14 of Set 1 | darovskoy
# Processing Record 15 of Set 1 | sitka
# Processing Record 16 of Set 1 | alyangula
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | novyy urengoy
# Processing Record 19 of Set 1 | kanker
# Processing Record 20 of Set 1 | progreso
# Processing Record 21 of Set 1 | roald
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | tiznit
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | port hedland
# Processing Record 27 of Set 1 | muroto
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | sinnamary
# Processing Record 30 of Set 1 | saint-augustin
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | sao francisco de paula
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | constitucion
# Processing Record 36 of Set 1 | dergachi
# Processing Record 37 of Set 1 | hambantota
# Processing Record 38 of Set 1 | hamilton
# Processing Record 39 of Set 1 | saint-georges
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | leningradskiy
# Processing Record 43 of Set 1 | inhambane
# Processing Record 44 of Set 1 | udachnyy
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | bubaque
# Processing Record 47 of Set 1 | lawrenceburg
# Processing Record 48 of Set 1 | egvekinot
# Processing Record 49 of Set 1 | caravelas
# Processing Record 50 of Set 1 | henties bay
# Processing Record 1 of Set 2 | souillac
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | atar
# Processing Record 6 of Set 2 | asau
# Processing Record 7 of Set 2 | obregon
# Processing Record 8 of Set 2 | murupara
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | lata
# Processing Record 12 of Set 2 | bonthe
# Processing Record 13 of Set 2 | manaure
# Processing Record 14 of Set 2 | mahebourg
# Processing Record 15 of Set 2 | oistins
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | banda aceh
# Processing Record 19 of Set 2 | kamaishi
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | lakatoro
# Processing Record 25 of Set 2 | ribeira brava
# Processing Record 26 of Set 2 | karratha
# Processing Record 27 of Set 2 | skegness
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | coahuayana
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | ketchikan
# Processing Record 33 of Set 2 | jalu
# Processing Record 34 of Set 2 | namatanai
# Processing Record 35 of Set 2 | kodiak
# Processing Record 36 of Set 2 | marrakesh
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | nenjiang
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | honiara
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | norfolk
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | erenhot
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | katsuura
# Processing Record 47 of Set 2 | ancud
# Processing Record 48 of Set 2 | chernyshevskiy
# Processing Record 49 of Set 2 | jawhar
# Processing Record 50 of Set 2 | mackay
# Processing Record 1 of Set 3 | slave lake
# Processing Record 2 of Set 3 | maputo
# Processing Record 3 of Set 3 | broken hill
# Processing Record 4 of Set 3 | adiake
# Processing Record 5 of Set 3 | sabha
# Processing Record 6 of Set 3 | lac du bonnet
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | virginia beach
# Processing Record 10 of Set 3 | teeswater
# Processing Record 11 of Set 3 | san quintin
# Processing Record 12 of Set 3 | haimen
# Processing Record 13 of Set 3 | filingue
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | prainha
# Processing Record 16 of Set 3 | emerald
# Processing Record 17 of Set 3 | manjacaze
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | verkhnevilyuysk
# Processing Record 20 of Set 3 | umm kaddadah
# Processing Record 21 of Set 3 | merauke
# Processing Record 22 of Set 3 | kulhudhuffushi
# Processing Record 23 of Set 3 | victoria
# Processing Record 24 of Set 3 | krk
# Processing Record 25 of Set 3 | billings
# Processing Record 26 of Set 3 | filadelfia
# Processing Record 27 of Set 3 | umkomaas
# Processing Record 28 of Set 3 | pierre
# Processing Record 29 of Set 3 | hovd
# Processing Record 30 of Set 3 | acapulco
# Processing Record 31 of Set 3 | kalevala
# Processing Record 32 of Set 3 | flin flon
# Processing Record 33 of Set 3 | brae
# Processing Record 34 of Set 3 | parker
# Processing Record 35 of Set 3 | hope
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | otane
# Processing Record 38 of Set 3 | luderitz
# Processing Record 39 of Set 3 | kalomo
# City not found. Skipping...
# Processing Record 40 of Set 3 | broome
# Processing Record 41 of Set 3 | victor harbor
# Processing Record 42 of Set 3 | dingle
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | kargil
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | dakar
# Processing Record 48 of Set 3 | padang
# Processing Record 49 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 3 | shimanovsk
# Processing Record 1 of Set 4 | olafsvik
# Processing Record 2 of Set 4 | chicama
# Processing Record 3 of Set 4 | belz
# Processing Record 4 of Set 4 | hofn
# Processing Record 5 of Set 4 | new norfolk
# Processing Record 6 of Set 4 | tazovskiy
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | sonoita
# Processing Record 9 of Set 4 | santa lucia
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 4 | te anau
# Processing Record 15 of Set 4 | ojinaga
# Processing Record 16 of Set 4 | bogotol
# Processing Record 17 of Set 4 | lorengau
# Processing Record 18 of Set 4 | esperance
# Processing Record 19 of Set 4 | ilulissat
# Processing Record 20 of Set 4 | nanortalik
# Processing Record 21 of Set 4 | olinda
# Processing Record 22 of Set 4 | agirish
# Processing Record 23 of Set 4 | cape town
# Processing Record 24 of Set 4 | butaritari
# Processing Record 25 of Set 4 | himatnagar
# Processing Record 26 of Set 4 | maumere
# Processing Record 27 of Set 4 | faanui
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | champerico
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | kismayo
# Processing Record 32 of Set 4 | lazaro cardenas
# Processing Record 33 of Set 4 | westport
# Processing Record 34 of Set 4 | natal
# Processing Record 35 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | flinders
# Processing Record 37 of Set 4 | laguna
# Processing Record 38 of Set 4 | qabis
# City not found. Skipping...
# Processing Record 39 of Set 4 | kozhva
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | homer
# Processing Record 42 of Set 4 | plettenberg bay
# Processing Record 43 of Set 4 | vallentuna
# Processing Record 44 of Set 4 | pahrump
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | geraldton
# Processing Record 47 of Set 4 | karangasem
# Processing Record 48 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 4 | portland
# Processing Record 1 of Set 5 | palmas
# Processing Record 2 of Set 5 | nchelenge
# Processing Record 3 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 5 | natalio
# Processing Record 7 of Set 5 | yuanping
# Processing Record 8 of Set 5 | kjollefjord
# Processing Record 9 of Set 5 | barrow
# Processing Record 10 of Set 5 | volosovo
# Processing Record 11 of Set 5 | nyazepetrovsk
# Processing Record 12 of Set 5 | hami
# Processing Record 13 of Set 5 | neverkino
# Processing Record 14 of Set 5 | mozarlandia
# Processing Record 15 of Set 5 | vilyuysk
# Processing Record 16 of Set 5 | jiaohe
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | amga
# Processing Record 19 of Set 5 | klaksvik
# Processing Record 20 of Set 5 | solnechnyy
# Processing Record 21 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 5 | makung
# City not found. Skipping...
# Processing Record 23 of Set 5 | sao joao da barra
# Processing Record 24 of Set 5 | mugur-aksy
# Processing Record 25 of Set 5 | bathsheba
# Processing Record 26 of Set 5 | moose factory
# Processing Record 27 of Set 5 | piacenza
# Processing Record 28 of Set 5 | tonstad
# Processing Record 29 of Set 5 | paciran
# Processing Record 30 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 5 | afyonkarahisar
# Processing Record 34 of Set 5 | gayeri
# Processing Record 35 of Set 5 | turukhansk
# Processing Record 36 of Set 5 | tamandare
# Processing Record 37 of Set 5 | georgetown
# Processing Record 38 of Set 5 | bakchar
# Processing Record 39 of Set 5 | north myrtle beach
# Processing Record 40 of Set 5 | barra patuca
# Processing Record 41 of Set 5 | dehloran
# Processing Record 42 of Set 5 | amazar
# Processing Record 43 of Set 5 | turbat
# Processing Record 44 of Set 5 | sebezh
# Processing Record 45 of Set 5 | komsomolskiy
# Processing Record 46 of Set 5 | darnah
# Processing Record 47 of Set 5 | mengcheng
# Processing Record 48 of Set 5 | mvomero
# Processing Record 49 of Set 5 | dawei
# Processing Record 50 of Set 5 | san patricio
# Processing Record 1 of Set 6 | itajobi
# Processing Record 2 of Set 6 | mana
# Processing Record 3 of Set 6 | kleck
# City not found. Skipping...
# Processing Record 4 of Set 6 | san andres
# Processing Record 5 of Set 6 | parana
# Processing Record 6 of Set 6 | nome
# Processing Record 7 of Set 6 | port macquarie
# Processing Record 8 of Set 6 | ponta do sol
# Processing Record 9 of Set 6 | margate
# Processing Record 10 of Set 6 | ostrovnoy
# Processing Record 11 of Set 6 | la ciotat
# Processing Record 12 of Set 6 | oyama
# Processing Record 13 of Set 6 | bethel
# Processing Record 14 of Set 6 | gzhatsk
# City not found. Skipping...
# Processing Record 15 of Set 6 | itarema
# Processing Record 16 of Set 6 | san ramon de la nueva oran
# Processing Record 17 of Set 6 | nago
# Processing Record 18 of Set 6 | fort morgan
# Processing Record 19 of Set 6 | nioro
# Processing Record 20 of Set 6 | north bend
# Processing Record 21 of Set 6 | cherskiy
# Processing Record 22 of Set 6 | pinar del rio
# Processing Record 23 of Set 6 | acajutla
# Processing Record 24 of Set 6 | luanda
# Processing Record 25 of Set 6 | pangai
# Processing Record 26 of Set 6 | boende
# Processing Record 27 of Set 6 | roros
# Processing Record 28 of Set 6 | labuhan
# Processing Record 29 of Set 6 | wanaraja
# Processing Record 30 of Set 6 | saint george
# Processing Record 31 of Set 6 | yumen
# Processing Record 32 of Set 6 | iqaluit
# Processing Record 33 of Set 6 | samarai
# Processing Record 34 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 6 | tilichiki
# Processing Record 36 of Set 6 | bilibino
# Processing Record 37 of Set 6 | gamba
# Processing Record 38 of Set 6 | zafra
# Processing Record 39 of Set 6 | bilma
# Processing Record 40 of Set 6 | tura
# Processing Record 41 of Set 6 | skibbereen
# Processing Record 42 of Set 6 | tuatapere
# Processing Record 43 of Set 6 | aykhal
# Processing Record 44 of Set 6 | upata
# Processing Record 45 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 6 | salekhard
# Processing Record 47 of Set 6 | carnarvon
# Processing Record 48 of Set 6 | mount hagen
# Processing Record 49 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 50 of Set 6 | lagoa
# Processing Record 1 of Set 7 | vila velha
# Processing Record 2 of Set 7 | shingu
# Processing Record 3 of Set 7 | caconda
# Processing Record 4 of Set 7 | saint-pierre
# Processing Record 5 of Set 7 | yantal
# Processing Record 6 of Set 7 | havelock
# Processing Record 7 of Set 7 | porto novo
# Processing Record 8 of Set 7 | umm lajj
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | los llanos de aridane
# Processing Record 11 of Set 7 | ribeira grande
# Processing Record 12 of Set 7 | airai
# Processing Record 13 of Set 7 | touros
# Processing Record 14 of Set 7 | itaituba
# Processing Record 15 of Set 7 | husavik
# Processing Record 16 of Set 7 | peskovka
# Processing Record 17 of Set 7 | isangel
# Processing Record 18 of Set 7 | gao
# Processing Record 19 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 20 of Set 7 | gizo
# Processing Record 21 of Set 7 | kysyl-syr
# Processing Record 22 of Set 7 | blairmore
# Processing Record 23 of Set 7 | impfondo
# Processing Record 24 of Set 7 | liverpool
# Processing Record 25 of Set 7 | cumra
# Processing Record 26 of Set 7 | salalah
# Processing Record 27 of Set 7 | xinan
# Processing Record 28 of Set 7 | avera
# Processing Record 29 of Set 7 | mirador
# Processing Record 30 of Set 7 | bengkulu
# Processing Record 31 of Set 7 | nara
# Processing Record 32 of Set 7 | coquimbo
# Processing Record 33 of Set 7 | kaeng khoi
# Processing Record 34 of Set 7 | singleton
# Processing Record 35 of Set 7 | praia
# Processing Record 36 of Set 7 | aguimes
# Processing Record 37 of Set 7 | almeirim
# Processing Record 38 of Set 7 | new ulm
# Processing Record 39 of Set 7 | bouna
# Processing Record 40 of Set 7 | altay
# Processing Record 41 of Set 7 | bagaces
# Processing Record 42 of Set 7 | panorama
# Processing Record 43 of Set 7 | buala
# Processing Record 44 of Set 7 | ushtobe
# Processing Record 45 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 7 | nigde
# Processing Record 47 of Set 7 | pangody
# Processing Record 48 of Set 7 | vallenar
# Processing Record 49 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 7 | rio gallegos
# Processing Record 1 of Set 8 | aklavik
# Processing Record 2 of Set 8 | hobyo
# Processing Record 3 of Set 8 | maliq
# Processing Record 4 of Set 8 | wanning
# Processing Record 5 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 6 of Set 8 | santa cruz de tenerife
# Processing Record 7 of Set 8 | kruisfontein
# Processing Record 8 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 8 | bombay
# Processing Record 10 of Set 8 | jackson
# Processing Record 11 of Set 8 | san jose de guanipa
# Processing Record 12 of Set 8 | sao bernardo
# Processing Record 13 of Set 8 | pevek
# Processing Record 14 of Set 8 | rupert
# Processing Record 15 of Set 8 | mantua
# Processing Record 16 of Set 8 | zheshart
# Processing Record 17 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 8 | yalchiki
# City not found. Skipping...
# Processing Record 19 of Set 8 | sobolevo
# Processing Record 20 of Set 8 | rawson
# Processing Record 21 of Set 8 | oranjemund
# Processing Record 22 of Set 8 | dunedin
# Processing Record 23 of Set 8 | sibolga
# Processing Record 24 of Set 8 | mao
# Processing Record 25 of Set 8 | bayir
# Processing Record 26 of Set 8 | ahipara
# Processing Record 27 of Set 8 | tchaourou
# Processing Record 28 of Set 8 | buta
# Processing Record 29 of Set 8 | bukavu
# Processing Record 30 of Set 8 | moiyabana
# City not found. Skipping...
# Processing Record 31 of Set 8 | cabedelo
# Processing Record 32 of Set 8 | mar del plata
# Processing Record 33 of Set 8 | pavilosta
# Processing Record 34 of Set 8 | enshi
# Processing Record 35 of Set 8 | manokwari
# Processing Record 36 of Set 8 | bobonong
# City not found. Skipping...
# Processing Record 37 of Set 8 | roma
# Processing Record 38 of Set 8 | derzhavinsk
# Processing Record 39 of Set 8 | ziniare
# Processing Record 40 of Set 8 | sterling
# Processing Record 41 of Set 8 | montanha
# Processing Record 42 of Set 8 | qaqortoq
# Processing Record 43 of Set 8 | east london
# Processing Record 44 of Set 8 | kavieng
# Processing Record 45 of Set 8 | peterhead
# Processing Record 46 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 8 | alice springs
# Processing Record 48 of Set 8 | chabahar
# Processing Record 49 of Set 8 | baghdad
# Processing Record 50 of Set 8 | doka
# Processing Record 1 of Set 9 | springbok
# Processing Record 2 of Set 9 | colac
# Processing Record 3 of Set 9 | biloela
# Processing Record 4 of Set 9 | mitikas
# Processing Record 5 of Set 9 | atambua
# Processing Record 6 of Set 9 | severo-kurilsk
# Processing Record 7 of Set 9 | neiafu
# Processing Record 8 of Set 9 | mildura
# Processing Record 9 of Set 9 | kiunga
# Processing Record 10 of Set 9 | shelburne
# Processing Record 11 of Set 9 | quesnel
# Processing Record 12 of Set 9 | kawalu
# Processing Record 13 of Set 9 | taoudenni
# Processing Record 14 of Set 9 | tagusao
# Processing Record 15 of Set 9 | skole
# Processing Record 16 of Set 9 | iguape
# Processing Record 17 of Set 9 | chililabombwe
# Processing Record 18 of Set 9 | saint-joseph
# Processing Record 19 of Set 9 | baiyin
# Processing Record 20 of Set 9 | najran
# Processing Record 21 of Set 9 | kerouane
# Processing Record 22 of Set 9 | svetlaya
# Processing Record 23 of Set 9 | iralaya
# Processing Record 24 of Set 9 | pangnirtung
# Processing Record 25 of Set 9 | juybar
# Processing Record 26 of Set 9 | santa isabel do rio negro
# Processing Record 27 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 9 | fengzhen
# Processing Record 29 of Set 9 | kurumkan
# Processing Record 30 of Set 9 | dongli
# Processing Record 31 of Set 9 | atbasar
# Processing Record 32 of Set 9 | birao
# Processing Record 33 of Set 9 | knokke-heist
# Processing Record 34 of Set 9 | alekseyevsk
# Processing Record 35 of Set 9 | quballat
# Processing Record 36 of Set 9 | nabire
# Processing Record 37 of Set 9 | slavutych
# Processing Record 38 of Set 9 | torbay
# Processing Record 39 of Set 9 | port blair
# Processing Record 40 of Set 9 | kannangad
# Processing Record 41 of Set 9 | duki
# Processing Record 42 of Set 9 | lompoc
# Processing Record 43 of Set 9 | grande prairie
# Processing Record 44 of Set 9 | jining
# Processing Record 45 of Set 9 | stillwater
# Processing Record 46 of Set 9 | ouesso
# Processing Record 47 of Set 9 | mahibadhoo
# Processing Record 48 of Set 9 | fuzhou
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 10 | havoysund
# Processing Record 2 of Set 10 | mehamn
# Processing Record 3 of Set 10 | tomatlan
# Processing Record 4 of Set 10 | mogadishu
# Processing Record 5 of Set 10 | kulachi
# Processing Record 6 of Set 10 | kirakira
# Processing Record 7 of Set 10 | uruacu
# Processing Record 8 of Set 10 | rocha
# Processing Record 9 of Set 10 | le port
# Processing Record 10 of Set 10 | vila franca do campo
# Processing Record 11 of Set 10 | portsmouth
# Processing Record 12 of Set 10 | tromso
# Processing Record 13 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 10 | aiquile
# Processing Record 15 of Set 10 | sibu
# Processing Record 16 of Set 10 | salinopolis
# Processing Record 17 of Set 10 | gravdal
# Processing Record 18 of Set 10 | kwinana
# Processing Record 19 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 20 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 10 | araouane
# Processing Record 22 of Set 10 | knysna
# Processing Record 23 of Set 10 | rapar
# Processing Record 24 of Set 10 | muravlenko
# Processing Record 25 of Set 10 | saldanha
# Processing Record 26 of Set 10 | kudymkar
# Processing Record 27 of Set 10 | angoram
# Processing Record 28 of Set 10 | terra santa
# Processing Record 29 of Set 10 | geylegphug
# City not found. Skipping...
# Processing Record 30 of Set 10 | pokhara
# Processing Record 31 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 10 | solwezi
# Processing Record 34 of Set 10 | maniitsoq
# Processing Record 35 of Set 10 | kungurtug
# Processing Record 36 of Set 10 | yulara
# Processing Record 37 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 38 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 39 of Set 10 | tessalit
# Processing Record 40 of Set 10 | kasangulu
# Processing Record 41 of Set 10 | fontaine
# Processing Record 42 of Set 10 | prince rupert
# Processing Record 43 of Set 10 | usinsk
# Processing Record 44 of Set 10 | aswan
# Processing Record 45 of Set 10 | coos bay
# Processing Record 46 of Set 10 | srednekolymsk
# Processing Record 47 of Set 10 | arroyo
# Processing Record 48 of Set 10 | tricase
# Processing Record 49 of Set 10 | miri
# Processing Record 50 of Set 10 | kahului
# Processing Record 1 of Set 11 | gagra
# Processing Record 2 of Set 11 | leeton
# Processing Record 3 of Set 11 | pacific grove
# Processing Record 4 of Set 11 | la rioja
# Processing Record 5 of Set 11 | millbrook
# Processing Record 6 of Set 11 | goderich
# Processing Record 7 of Set 11 | mount gambier
# Processing Record 8 of Set 11 | cabra
# Processing Record 9 of Set 11 | shepsi
# Processing Record 10 of Set 11 | play cu
# City not found. Skipping...
# Processing Record 11 of Set 11 | middlesex
# Processing Record 12 of Set 11 | cidreira
# Processing Record 13 of Set 11 | florence
# Processing Record 14 of Set 11 | olhao
# Processing Record 15 of Set 11 | maiduguri
# Processing Record 16 of Set 11 | port pirie
# Processing Record 17 of Set 11 | bairiki
# Processing Record 18 of Set 11 | kasongo-lunda
# Processing Record 19 of Set 11 | anadyr
# Processing Record 20 of Set 11 | port hardy
# Processing Record 21 of Set 11 | plaster rock
# Processing Record 22 of Set 11 | manuel doblado
# City not found. Skipping...
# Processing Record 23 of Set 11 | heihe
# Processing Record 24 of Set 11 | talnakh
# Processing Record 25 of Set 11 | coihaique
# Processing Record 26 of Set 11 | homnabad
# Processing Record 27 of Set 11 | iberia
# Processing Record 28 of Set 11 | hazorasp
# Processing Record 29 of Set 11 | fuyang
# Processing Record 30 of Set 11 | azovo
# Processing Record 31 of Set 11 | calvinia
# Processing Record 32 of Set 11 | dukat
# Processing Record 33 of Set 11 | mount isa
# Processing Record 34 of Set 11 | olavarria
# Processing Record 35 of Set 11 | piqua
# Processing Record 36 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 11 | otjimbingwe
# Processing Record 38 of Set 11 | winslow
# Processing Record 39 of Set 11 | mankono
# Processing Record 40 of Set 11 | lengshuitan
# Processing Record 41 of Set 11 | murray bridge
# Processing Record 42 of Set 11 | mushie
# Processing Record 43 of Set 11 | murindo
# Processing Record 44 of Set 11 | srivardhan
# Processing Record 45 of Set 11 | arroyohondo
# Processing Record 46 of Set 11 | jieshi
# Processing Record 47 of Set 11 | storsteinnes
# Processing Record 48 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 11 | palkaka
# City not found. Skipping...
# Processing Record 50 of Set 11 | galle
# Processing Record 1 of Set 12 | bud
# Processing Record 2 of Set 12 | marzuq
# Processing Record 3 of Set 12 | korla
# Processing Record 4 of Set 12 | nuuk
# Processing Record 5 of Set 12 | macklin
# Processing Record 6 of Set 12 | ixtapa
# Processing Record 7 of Set 12 | yurla
# Processing Record 8 of Set 12 | haines junction
# Processing Record 9 of Set 12 | warwick
# Processing Record 10 of Set 12 | shache
# Processing Record 11 of Set 12 | kerema
# Processing Record 12 of Set 12 | buchanan
# Processing Record 13 of Set 12 | cardenas
# Processing Record 14 of Set 12 | mudon
# Processing Record 15 of Set 12 | deputatskiy
# Processing Record 16 of Set 12 | rehoboth
# Processing Record 17 of Set 12 | penjamo
# Processing Record 18 of Set 12 | faya
# Processing Record 19 of Set 12 | richards bay
# Processing Record 20 of Set 12 | lollar
# Processing Record 21 of Set 12 | nanakuli
# Processing Record 22 of Set 12 | gat
# Processing Record 23 of Set 12 | kyzyl-mazhalyk
# Processing Record 24 of Set 12 | baker city
# Processing Record 25 of Set 12 | takoradi
# Processing Record 26 of Set 12 | ipixuna
# Processing Record 27 of Set 12 | bull savanna
# Processing Record 28 of Set 12 | wewak
# Processing Record 29 of Set 12 | loubomo
# Processing Record 30 of Set 12 | moranbah
# Processing Record 31 of Set 12 | bow island
# Processing Record 32 of Set 12 | vao
# Processing Record 33 of Set 12 | okhotsk
# Processing Record 34 of Set 12 | garowe
# Processing Record 35 of Set 12 | jaffna
# Processing Record 36 of Set 12 | troitskoye
# Processing Record 37 of Set 12 | nouakchott
# Processing Record 38 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 12 | oktyabrskoye
# Processing Record 40 of Set 12 | kisarawe
# Processing Record 41 of Set 12 | antropovo
# Processing Record 42 of Set 12 | kendari
# Processing Record 43 of Set 12 | khorixas
# Processing Record 44 of Set 12 | san vicente
# Processing Record 45 of Set 12 | sogne
# Processing Record 46 of Set 12 | severobaykalsk
# Processing Record 47 of Set 12 | yinchuan
# Processing Record 48 of Set 12 | itoman
# Processing Record 49 of Set 12 | harper
# Processing Record 50 of Set 12 | ozernovskiy
# Processing Record 1 of Set 13 | port keats
# Processing Record 2 of Set 13 | cleburne
# Processing Record 3 of Set 13 | lavrentiya
# Processing Record 4 of Set 13 | fukue
# Processing Record 5 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 13 | ratnagiri
# Processing Record 7 of Set 13 | oriximina
# Processing Record 8 of Set 13 | catalina foothills
# Processing Record 9 of Set 13 | yar-sale
# Processing Record 10 of Set 13 | manuk mangkaw
# Processing Record 11 of Set 13 | san ramon
# Processing Record 12 of Set 13 | quatre cocos
# Processing Record 13 of Set 13 | norman wells
# Processing Record 14 of Set 13 | santa fe
# Processing Record 15 of Set 13 | doha
# Processing Record 16 of Set 13 | muyezerskiy
# Processing Record 17 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 13 | gora kalwaria
# Processing Record 19 of Set 13 | muros
# Processing Record 20 of Set 13 | lamont
# Processing Record 21 of Set 13 | port moresby
# Processing Record 22 of Set 13 | manono
# Processing Record 23 of Set 13 | amapa
# Processing Record 24 of Set 13 | vitimskiy
# City not found. Skipping...
# Processing Record 25 of Set 13 | mehriz
# Processing Record 26 of Set 13 | kraslava
# Processing Record 27 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 28 of Set 13 | xinmin
# Processing Record 29 of Set 13 | huarmey
# Processing Record 30 of Set 13 | harer
# Processing Record 31 of Set 13 | pisco
# Processing Record 32 of Set 13 | kropotkin
# Processing Record 33 of Set 13 | imeni poliny osipenko
# Processing Record 34 of Set 13 | waingapu
# Processing Record 35 of Set 13 | vestmannaeyjar
# Processing Record 36 of Set 13 | seydisehir
# Processing Record 37 of Set 13 | brownwood
# Processing Record 38 of Set 13 | ucluelet
# Processing Record 39 of Set 13 | waipawa
# Processing Record 40 of Set 13 | ibra
# Processing Record 41 of Set 13 | puerto carreno
# Processing Record 42 of Set 13 | thap than
# Processing Record 43 of Set 13 | cururupu
# Processing Record 44 of Set 13 | saint-leu
# Processing Record 45 of Set 13 | morondava
# Processing Record 46 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 47 of Set 13 | sokolo
# Processing Record 48 of Set 13 | oneonta
# Processing Record 49 of Set 13 | phalaborwa
# Processing Record 50 of Set 13 | ialibu
# Processing Record 1 of Set 14 | sorland
# Processing Record 2 of Set 14 | aksay
# Processing Record 3 of Set 14 | braganca
# Processing Record 4 of Set 14 | kalamnuri
# Processing Record 5 of Set 14 | ubinskoye
# Processing Record 6 of Set 14 | loudi
# Processing Record 7 of Set 14 | erechim
# Processing Record 8 of Set 14 | orlik
# Processing Record 9 of Set 14 | edd
# Processing Record 10 of Set 14 | bethanien
# Processing Record 11 of Set 14 | puerto suarez
# Processing Record 12 of Set 14 | bismarck
# Processing Record 13 of Set 14 | plouzane
# Processing Record 14 of Set 14 | grindavik
# Processing Record 15 of Set 14 | ishigaki
# Processing Record 16 of Set 14 | miranda de ebro
# Processing Record 17 of Set 14 | sestroretsk
# Processing Record 18 of Set 14 | franklin
# Processing Record 19 of Set 14 | nikko
# Processing Record 20 of Set 14 | romodanovo
# Processing Record 21 of Set 14 | puerto escondido
# Processing Record 22 of Set 14 | poykovskiy
# Processing Record 23 of Set 14 | tepetitla
# Processing Record 24 of Set 14 | tiksi
# Processing Record 25 of Set 14 | zhanakorgan
# Processing Record 26 of Set 14 | comodoro rivadavia
# Processing Record 27 of Set 14 | iquique
# Processing Record 28 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 14 | presidencia roque saenz pena
# Processing Record 30 of Set 14 | serenje
# Processing Record 31 of Set 14 | babu
# Processing Record 32 of Set 14 | suntar
# Processing Record 33 of Set 14 | biak
# Processing Record 34 of Set 14 | burns lake
# Processing Record 35 of Set 14 | lagos
# Processing Record 36 of Set 14 | sao miguel do araguaia
# Processing Record 37 of Set 14 | ust-nera
# Processing Record 38 of Set 14 | urla
# Processing Record 39 of Set 14 | meulaboh
# Processing Record 40 of Set 14 | balakhninskiy
# Processing Record 41 of Set 14 | cedar city
# Processing Record 42 of Set 14 | wasilla
# Processing Record 43 of Set 14 | mehran
# Processing Record 44 of Set 14 | utiel
# Processing Record 45 of Set 14 | twin falls
# Processing Record 46 of Set 14 | kerman
# Processing Record 47 of Set 14 | beyneu
# Processing Record 48 of Set 14 | kinshasa
# Processing Record 49 of Set 14 | gubkinskiy
# Processing Record 50 of Set 14 | urusha
# Processing Record 1 of Set 15 | walvis bay
# Processing Record 2 of Set 15 | cap malheureux
# Processing Record 3 of Set 15 | byron bay
# Processing Record 4 of Set 15 | ambon
# Processing Record 5 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 6 of Set 15 | beauchamps
# Processing Record 7 of Set 15 | ashibetsu
# Processing Record 8 of Set 15 | queimadas
# Processing Record 9 of Set 15 | grand-santi
# Processing Record 10 of Set 15 | college
# Processing Record 11 of Set 15 | pumiao
# Processing Record 12 of Set 15 | itapeva
# Processing Record 13 of Set 15 | taywarah
# Processing Record 14 of Set 15 | marquette
# Processing Record 15 of Set 15 | fort nelson
# Processing Record 16 of Set 15 | fukuma
# Processing Record 17 of Set 15 | tarakan
# Processing Record 18 of Set 15 | taihe
# Processing Record 19 of Set 15 | guerrero negro
# Processing Record 20 of Set 15 | chapais
# Processing Record 21 of Set 15 | graaff-reinet
# Processing Record 22 of Set 15 | ladybrand
# Processing Record 23 of Set 15 | ahualulco
# Processing Record 24 of Set 15 | svetlogorsk
# Processing Record 25 of Set 15 | ambovombe
# Processing Record 26 of Set 15 | sumenep
# Processing Record 27 of Set 15 | luleburgaz
# Processing Record 28 of Set 15 | kaka
# Processing Record 29 of Set 15 | tabou
# Processing Record 30 of Set 15 | aboisso
# Processing Record 31 of Set 15 | voskresenskoye
# Processing Record 32 of Set 15 | pavlodar
# Processing Record 33 of Set 15 | jiaocheng
# Processing Record 34 of Set 15 | kudahuvadhoo
# Processing Record 35 of Set 15 | corowa
# Processing Record 36 of Set 15 | kavaratti
# Processing Record 37 of Set 15 | marsaxlokk
# Processing Record 38 of Set 15 | krikellos
# Processing Record 39 of Set 15 | el progreso
# Processing Record 40 of Set 15 | patrocinio
# Processing Record 41 of Set 15 | freeport
# Processing Record 42 of Set 15 | ivanovka
# Processing Record 43 of Set 15 | okha
# Processing Record 44 of Set 15 | san francisco del mar
# Processing Record 45 of Set 15 | baykit
# Processing Record 46 of Set 15 | neuquen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ridgefield  40.8343  -74.0088     53.92        84          90
# 1  Punta Arenas -53.1500  -70.9167     39.31        75          75
# 2     Upernavik  72.7868  -56.1549      4.35        87          40
# 3     Fairbanks  64.8378 -147.7164    -10.39        75           1
# 4        Atuona  -9.8000 -139.0333     78.26        74         100
# 5      Hermanus -34.4187   19.2345     65.89        91         100
# 6         Kapaa  22.0752 -159.3190     82.38        71          40
# 7      La Ronge  55.1001 -105.2842     12.45        79          90
# 8      Chumikan  54.7183  135.3150      6.80        76         100
# 9       Rikitea -23.1203 -134.9692     74.61        61           4
#
#    Wind Speed Country Current Description                 Date
# 0        5.75      US             drizzle  2021-11-22 02:46:33
# 1       25.32      CL       broken clouds  2021-11-22 02:51:11
# 2        6.62      GL    scattered clouds  2021-11-22 02:51:12
# 3        0.00      US           clear sky  2021-11-22 02:48:50
# 4       10.78      PF     overcast clouds  2021-11-22 02:51:12
# 5       17.11      ZA          light rain  2021-11-22 02:51:13
# 6        3.00      US    scattered clouds  2021-11-22 02:51:13
# 7        8.05      CA   light shower snow  2021-11-22 02:51:13
# 8        2.30      RU     overcast clouds  2021-11-22 02:51:14
# 9        3.94      PF           clear sky  2021-11-22 02:51:14

# %% [markdown]
# ## Export to CVS

# %%
# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]

# %%
city_data_df.head(10)
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Ridgefield  40.8343  -74.0088     53.92        84          90
# 1             Punta Arenas -53.1500  -70.9167     39.31        75          75
# 2                Upernavik  72.7868  -56.1549      4.35        87          40
# 3                Fairbanks  64.8378 -147.7164    -10.39        75           1
# 4                   Atuona  -9.8000 -139.0333     78.26        74         100
# ..                     ...      ...       ...       ...       ...         ...
# 683               Ivanovka  42.8878   75.0850     34.23        48          53
# 684                   Okha  53.5739  142.9478     28.98        77          74
# 685  San Francisco Del Mar  16.2333  -94.6500     79.20        74           1
# 686                 Baykit  61.6700   96.3700      5.32        97         100
# 687                Neuquen -38.9516  -68.0591     75.09        35           0
#
#      Wind Speed Country Current Description                 Date
# 0          5.75      US             drizzle  2021-11-22 02:46:33
# 1         25.32      CL       broken clouds  2021-11-22 02:51:11
# 2          6.62      GL    scattered clouds  2021-11-22 02:51:12
# 3          0.00      US           clear sky  2021-11-22 02:48:50
# 4         10.78      PF     overcast clouds  2021-11-22 02:51:12
# ..          ...     ...                 ...                  ...
# 683        3.58      KG       broken clouds  2021-11-22 03:10:22
# 684       13.13      RU       broken clouds  2021-11-22 03:10:22
# 685       22.21      MX           clear sky  2021-11-22 03:10:23
# 686        3.02      RU     overcast clouds  2021-11-22 03:10:23
# 687       12.66      AR           clear sky  2021-11-22 03:09:22
#
# [688 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
